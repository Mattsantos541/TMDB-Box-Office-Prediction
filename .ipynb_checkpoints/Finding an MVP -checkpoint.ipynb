# %%
#RMSE will be the evaulation metric
#The Baseline is the Mean revenue for all the Films

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from math import sqrt
import warnings
from sklearn.model_selection import cross_val_score
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ### importing the data

# %%
df= pd.read_csv('train.csv')

# %%
df.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 23 columns]

# %%
df=pd.DataFrame(df)

# %%
#Cleaning the data set, dropping irrelevant columns for Training Data

# %%
train=df.drop(columns=['belongs_to_collection', 'genres', 'poster_path', 'homepage', 'imdb_id', 'original_title', 'overview', 'status', 'Keywords', 'tagline', 'cast', 'crew', 'production_companies', 'production_countries', 'spoken_languages'])

# %%
train= train.dropna()
train.isnull().sum()
# Out:
# id                   0
# budget               0
# original_language    0
# popularity           0
# release_date         0
# runtime              0
# title                0
# revenue              0
# dtype: int64

# %%
#Test data set
test = pd.read_csv('test.csv')

# %%
test= pd.DataFrame(test)

# %%
test=test.drop(columns=['belongs_to_collection', 'genres', 'poster_path', 'homepage', 'imdb_id', 'original_title', 'overview', 'status', 'Keywords', 'tagline', 'cast', 'crew', 'production_companies', 'production_countries', 'spoken_languages'])

# %% [markdown]
# Will Put the Test Data aside and work exclusively with train data, until the end to project the revenue

# %% [markdown]
# ##### Visualization and Exploration

# %%
correlation = train.corr() #corr() method of pandas library calculates correlation between columns of dataframe
sns.heatmap(correlation,cmap="YlGnBu",annot=True)
plt.show()

# %%
with sns.axes_style('white'):
    j = sns.jointplot("budget", "revenue", data=train, kind='reg', height=5);
plt.show()

# %%
g = sns.PairGrid(train)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);

# %%
#Looking for correlations
corr_matrix= train.corr()

# %%
#looking at each attribute's correlation
corr_matrix['revenue'].sort_values(ascending=False)
# Out:
# revenue       1.000000
# budget        0.752924
# popularity    0.461347
# runtime       0.216380
# id            0.000729
# Name: revenue, dtype: float64

# %% [markdown]
# #### For MVP Use Budget and runtime to predict Revenue

# %%
#training / test split
X= train[['budget', 'runtime']]
y= train['revenue']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .20, random_state = 123)

#X_train = X_train.reshape(-1, 1)
#X_test = X_test.reshape(-1, 1)

X_train.head()
# Out:
#         budget  runtime
# 618    4500000     90.0
# 1704  42000000    100.0
# 2441   3000000     95.0
# 1309  61000000    145.0
# 2257   7000000    114.0

# %%
#First model will be with linear regression target= revenue, input= budget, runtime

# %%
lm1 = LinearRegression()

print(lm1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm1.fit(X_train, y_train)
print("Linear Model:", lm1)

lm1_y_intercept = lm1.intercept_
print("intercept: ", lm1_y_intercept)

lm1_coefficients = lm1.coef_
print("coefficients: ", lm1_coefficients)
# Out:
# Linear Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# intercept:  -20801394.326345444
# coefficients:  [2.72274682e+00 2.38085714e+05]

# %% [markdown]
# #Given the intercept and the coefficients, we can write the regression function.
#
# #print('{} = b + m1 * {} + m2 * {}'.format(y_train.columns[0], X_train.columns[0],X_train.columns[1]))
# print('    y-intercept  (b): %.2f' % lm1_y_intercept)
# print('    coefficient (m1): %.2f' % lm1_coefficients[0][0])
# print('    coefficient (m2): %.2f' % lm1_coefficients[0][1])

# %%
#Insample predictions
y_pred_lm1 = lm1.predict(X_train)

# %%
mse_lm1 = mean_squared_error(y_train, y_pred_lm1)
print("linear model\n  mean squared error: {:.3}".format(mse_lm1)) 

r2_lm1 = r2_score(y_train, y_pred_lm1)
print((r2_lm1))
# Out:
# linear model
#   mean squared error: 8.59e+15
# 0.5380320995648751

# %%
from math import sqrt
RMSE = sqrt(mse_lm1)

print("RMSE = ", RMSE)
# Out:
# RMSE =  92670238.24291968

# %%
#### Will use popularity along with MVP

# %%
#training / test split
X= train[['budget', 'runtime', 'popularity']]
y= train['revenue']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .20, random_state = 123)

#X_train = X_train.reshape(-1, 1)
#X_test = X_test.reshape(-1, 1)

X_train.head()
# Out:
#         budget  runtime  popularity
# 618    4500000     90.0   14.658885
# 1704  42000000    100.0   10.174298
# 2441   3000000     95.0    4.947043
# 1309  61000000    145.0  154.801009
# 2257   7000000    114.0    6.012720

# %%
lm1 = LinearRegression()

print(lm1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm1.fit(X_train, y_train)
print("Linear Model:", lm1)

lm1_y_intercept = lm1.intercept_
print("intercept: ", lm1_y_intercept)

lm1_coefficients = lm1.coef_
print("coefficients: ", lm1_coefficients)
# Out:
# Linear Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# intercept:  -30218748.831345245
# coefficients:  [2.37990035e+00 1.35543442e+05 3.41042447e+06]

# %%
#Insample predictions
y_pred_lm1 = lm1.predict(X_train)

# %%
mse_lm1 = mean_squared_error(y_train, y_pred_lm1)
print("linear model\n  mean squared error: {:.3}".format(mse_lm1)) 

r2_lm1 = r2_score(y_train, y_pred_lm1)
print((r2_lm1))
# Out:
# linear model
#   mean squared error: 7.5e+15
# 0.5965693177241678

# %%
from math import sqrt
RMSE = sqrt(mse_lm1)

print("RMSE = ", RMSE)
# Out:
# RMSE =  86600189.4171985
