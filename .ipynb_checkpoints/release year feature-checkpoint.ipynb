# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from math import sqrt
import warnings
from sklearn.model_selection import cross_val_score
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import re as r

# %%
df_orig= pd.read_csv('df_base')

# %%
df= df_orig.head()
df.head(1)
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
#
#      budget                          genres homepage    imdb_id  \
# 0  14000000  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
#
#   original_language          original_title  \
# 0                en  Hot Tub Time Machine 2
#
#                                             overview  ...  release_date  \
# 0  When Lou, who has become the "father of the In...  ...       2/20/15
#
#   runtime                          spoken_languages    status  \
# 0    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
#
# [1 rows x 24 columns]

# %%
df= df_orig.drop(columns=['poster_path', 'original_language','homepage', 'imdb_id', 'overview', 'status', 'Keywords', 'tagline', 'cast', 'crew', 'production_companies', 'production_countries', 'spoken_languages'])

# %%
#need to get rid of nulls and replace with '0'
df= df.fillna(0)
#All films that beloing to a collection (book, franchise, etc.) assigned a 1

df.head()
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                  0
# 3           3   4                                                  0
# 4           4   5                                                  0
#
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                              original_title  popularity release_date  runtime  \
# 0                    Hot Tub Time Machine 2    6.575393      2/20/15     93.0
# 1  The Princess Diaries 2: Royal Engagement    8.248895       8/6/04    113.0
# 2                                  Whiplash   64.299990     10/10/14    105.0
# 3                                   Kahaani    3.174936       3/9/12    122.0
# 4                                      마린보이    1.148070       2/5/09    118.0
#
#                                       title   revenue
# 0                    Hot Tub Time Machine 2  12314651
# 1  The Princess Diaries 2: Royal Engagement  95149435
# 2                                  Whiplash  13092000
# 3                                   Kahaani  16000000
# 4                                Marine Boy   3923970

# %%
# create date related features
df.release_date = pd.to_datetime(df.release_date)
df['release_year'] = df.release_date.dt.year
df['release_year'] = df.release_year.apply(lambda x: x-100 if x > 2020 else x)

# %%
df= df.drop(columns= ['release_date'])

# %%
#create a feature that is gross profit pct_profit
df['gross_profit']= df['revenue']- df['budget']

# %%
#Creating a pct profit column
df['pct_profit']= (df['gross_profit']/df['revenue']*100).round(2)

# %%
df.head()
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                  0
# 3           3   4                                                  0
# 4           4   5                                                  0
#
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                              original_title  popularity  runtime  \
# 0                    Hot Tub Time Machine 2    6.575393     93.0
# 1  The Princess Diaries 2: Royal Engagement    8.248895    113.0
# 2                                  Whiplash   64.299990    105.0
# 3                                   Kahaani    3.174936    122.0
# 4                                      마린보이    1.148070    118.0
#
#                                       title   revenue  release_year  \
# 0                    Hot Tub Time Machine 2  12314651          2015
# 1  The Princess Diaries 2: Royal Engagement  95149435          2004
# 2                                  Whiplash  13092000          2014
# 3                                   Kahaani  16000000          2012
# 4                                Marine Boy   3923970          2009
#
#    gross_profit  pct_profit
# 0      -1685349      -13.69
# 1      55149435       57.96
# 2       9792000       74.79
# 3      14800000       92.50
# 4       3923970      100.00

# %%
plt.hist(df['release_year'])
# Out:
# (array([  11.,   19.,   21.,   41.,   54.,   84.,  332.,  467.,  832.,
#         1139.]),
#  array([1921. , 1930.6, 1940.2, 1949.8, 1959.4, 1969. , 1978.6, 1988.2,
#         1997.8, 2007.4, 2017. ]),
#  <a list of 10 Patch objects>)

# %%
corr_matrix= df.corr()

# %%
corr_matrix['pct_profit'].sort_values(ascending=False)
# Out:
# pct_profit      1.000000
# gross_profit    0.021035
# revenue         0.019515
# runtime         0.019130
# id              0.016261
# Unnamed: 0      0.016261
# popularity      0.012813
# budget          0.008671
# release_year   -0.005409
# Name: pct_profit, dtype: float64

# %%
corr_matrix= df.corr()
df['release_year'].describe()
# Out:
# count    3000.000000
# mean     1999.713000
# std        15.423313
# min      1921.000000
# 25%      1993.000000
# 50%      2004.000000
# 75%      2011.000000
# max      2017.000000
# Name: release_year, dtype: float64

# %%
plt.boxplot(df['release_year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a3058cf28>,
#   <matplotlib.lines.Line2D at 0x1a3058cef0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a304a95f8>,
#   <matplotlib.lines.Line2D at 0x1a304a9940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a3058cb70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a304a9c88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a304a9fd0>],
#  'means': []}

# %%
#grouped health scores into 4 groups
release_time= {'release_time' : []}
for x in df['release_year']:
#     print(x)
    if x > 2010:
        release_time['release_time'].append('1')
    elif x>=2005:
        release_time['release_time'].append('2')
    elif x >=2000:
        release_time['release_time'].append('3')
    elif x >= 1995:
        release_time['release_time'].append('4')
    elif x >= 1990:
        release_time['release_time'].append('5')
    else:
        release_time['release_time'].append('6')

#df
df['release_time']= release_time['release_time']

# %%
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                  0
# 3           3   4                                                  0
# 4           4   5                                                  0
#
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                              original_title  popularity  runtime  \
# 0                    Hot Tub Time Machine 2    6.575393     93.0
# 1  The Princess Diaries 2: Royal Engagement    8.248895    113.0
# 2                                  Whiplash   64.299990    105.0
# 3                                   Kahaani    3.174936    122.0
# 4                                      마린보이    1.148070    118.0
#
#                                       title   revenue  release_year  \
# 0                    Hot Tub Time Machine 2  12314651          2015
# 1  The Princess Diaries 2: Royal Engagement  95149435          2004
# 2                                  Whiplash  13092000          2014
# 3                                   Kahaani  16000000          2012
# 4                                Marine Boy   3923970          2009
#
#    gross_profit  pct_profit release_time
# 0      -1685349      -13.69            1
# 1      55149435       57.96            3
# 2       9792000       74.79            1
# 3      14800000       92.50            1
# 4       3923970      100.00            2

# %%
corr_matrix['pct_profit'].sort_values(ascending=False)
# Out:
# pct_profit      1.000000
# gross_profit    0.021035
# revenue         0.019515
# runtime         0.019130
# id              0.016261
# Unnamed: 0      0.016261
# popularity      0.012813
# budget          0.008671
# release_year   -0.005409
# Name: pct_profit, dtype: float64
